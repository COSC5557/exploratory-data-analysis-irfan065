# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

data = pd.read_csv('wineq.csv')


print("Missing Values:")
print(data.isnull().sum())

sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))
for i, column in enumerate(data.columns[:-1]):
    plt.subplot(3, 4, i + 1)
    sns.kdeplot(data[column], fill=True, color='skyblue')
    plt.title(column)

plt.tight_layout()
plt.show()

scaler = MinMaxScaler()
data.iloc[:, :-1] = scaler.fit_transform(data.iloc[:, :-1])

plt.figure(figsize=(15, 10))
for i, column in enumerate(data.columns[:-1]):
    plt.subplot(3, 4, i + 1)
    sns.kdeplot(data[column], fill=True, color='lightcoral')
    plt.title(column + " (After Normalization)")

plt.tight_layout()
plt.show()
# Out:
# Missing Values:
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
